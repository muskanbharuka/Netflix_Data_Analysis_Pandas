# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Downloads\netflixData.csv")
df
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
df.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
df.shape        
# df.size
# Out:
# (5967, 13)

# %%
df.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Production Country', 'Release Date', 'Rating', 'Duration',
#        'Imdb Score', 'Content Type', 'Date Added'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Show Id                object
# Title                  object
# Description            object
# Director               object
# Genres                 object
# Cast                   object
# Production Country     object
# Release Date          float64
# Rating                 object
# Duration               object
# Imdb Score             object
# Content Type           object
# Date Added             object
# dtype: object

# %%
df['Release Date'] = df['Release Date'].fillna(0).astype(int)
# df['Release Date'].isna().sum()  # Shows how many missing values
df['Release Date']
# Out:
# 0       2020
# 1       2020
# 2       2019
# 3       2020
# 4       2020
#         ...
# 5962    2009
# 5963    2019
# 5964    2016
# 5965    2017
# 5966    2018
# Name: Release Date, Length: 5967, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             5967 non-null   object
#  1   Title               5967 non-null   object
#  2   Description         5967 non-null   object
#  3   Director            3903 non-null   object
#  4   Genres              5967 non-null   object
#  5   Cast                5437 non-null   object
#  6   Production Country  5408 non-null   object
#  7   Release Date        5967 non-null   int32
#  8   Rating              5963 non-null   object
#  9   Duration            5964 non-null   object
#  10  Imdb Score          5359 non-null   object
#  11  Content Type        5967 non-null   object
#  12  Date Added          4632 non-null   object
# dtypes: int32(1), object(12)
# memory usage: 582.8+ KB

# %%
df.describe()
# Out:
#        Release Date
# count   5967.000000
# mean    2014.630468
# std       45.766834
# min        0.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# #### Is there duplicate records here , if yes the remove it ?

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added]
# Index: []

# %%
# df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Is there any null value in any columns , Show with heatmap

# %%
df.isnull()
# Out:
#       Show Id  Title  Description  Director  Genres   Cast  \
# 0       False  False        False      True   False   True
# 1       False  False        False     False   False  False
# 2       False  False        False     False   False  False
# 3       False  False        False      True   False  False
# 4       False  False        False     False   False   True
# ...       ...    ...          ...       ...     ...    ...
# 5962    False  False        False     False   False  False
# 5963    False  False        False      True   False  False
# 5964    False  False        False      True   False  False
# 5965    False  False        False     False   False  False
# 5966    False  False        False     False   False  False
#
#       Production Country  Release Date  Rating  Duration  Imdb Score  \
# 0                  False         False   False     False       False
# 1                  False         False   False     False       False
# ...

# %%
df.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             0
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
sns.heatmap(df.isnull(),annot=True)
# Out:
# <Axes: >

# %%
df
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %% [markdown]
# #### For 2 States who is the director and what s showID

# %%
# df[500:550].head(50)

# %%
df[df['Title'] == '2 States']
# Out:
#                                  Show Id     Title  \
# 32  79afe5bd-0dcd-4cac-9072-f77f46f355ef  2 States
#
#                                           Description         Director  \
# 32  Graduate students Krish and Ananya hope to win...  Abhishek Varman
#
#                                     Genres  \
# 32  Comedies, Dramas, International Movies
#
#                                                  Cast Production Country  \
# 32  Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...              India
#
#     Release Date Rating Duration Imdb Score Content Type      Date Added
# 32          2014  TV-PG  143 min     7.0/10        Movie  August 4, 2018

# %%
df[df['Title'].str.contains('2 States')]
# Out:
#                                  Show Id     Title  \
# 32  79afe5bd-0dcd-4cac-9072-f77f46f355ef  2 States
#
#                                           Description         Director  \
# 32  Graduate students Krish and Ananya hope to win...  Abhishek Varman
#
#                                     Genres  \
# 32  Comedies, Dramas, International Movies
#
#                                                  Cast Production Country  \
# 32  Alia Bhatt, Arjun Kapoor, Ronit Roy, Amrita Si...              India
#
#     Release Date Rating Duration Imdb Score Content Type      Date Added
# 32          2014  TV-PG  143 min     7.0/10        Movie  August 4, 2018

# %% [markdown]
# #### In which year highest number of series/movies released , Show with bar graph

# %%
# new column converting release date to datetime
df['Date'] = pd.to_datetime(df['Release Date'],format='%Y',errors='coerce')
df
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
df.dtypes
# Out:
# Show Id                       object
# Title                         object
# Description                   object
# Director                      object
# Genres                        object
# Cast                          object
# Production Country            object
# Release Date                   int32
# Rating                        object
# Duration                      object
# Imdb Score                    object
# Content Type                  object
# Date Added                    object
# Date                  datetime64[ns]
# dtype: object

# %%
df['Date'].dt.year.value_counts()
# Out:
# Date
# 2019.0    971
# 2020.0    946
# 2018.0    924
# 2017.0    661
# 2016.0    491
#          ...
# 1977.0      1
# 1945.0      1
# 1966.0      1
# 1956.0      1
# 1959.0      1
# Name: count, Length: 65, dtype: int64

# %%
df['Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### How many movies and TV shows are in dataset , show with bar graph

# %%
df.groupby('Content Type')['Content Type'].count()
# Out:
# Content Type
# Movie      3867
# TV Show    2100
# Name: Content Type, dtype: int64

# %%
sns.countplot(x='Content Type', data=df)
# Out:
# <Axes: xlabel='Content Type', ylabel='count'>

# %% [markdown]
# #### Show all movies released in year 2000

# %%
# df['Year'] = df['Date'].dt.year
df[(df['Release Date']==2000) & (df['Content Type']=="Movie")]
# Out:
#                                    Show Id  \
# 562   dc0d2072-65fe-471a-90e9-872e01f9f6d0
# 940   6bbd0936-dae4-46a6-9933-ce8e17442235
# 1652  94a38abb-8990-4fbd-87b5-5aba0c15f89a
# 2417  434ed003-d3f5-418c-8892-fc79318fa506
# 3176  2f0addb7-77ea-46d9-98a1-dd814dcc9ee5
# 3689  0d008ec4-fd9a-489c-a31e-cbb21f5d8ece
# 4022  3fe8a1ce-c9e8-423b-bab3-626974bfa476
# 4317  de7dbd94-052f-4286-aa15-e47d5e4d5b5f
# 5110  bbc5cd38-3999-4cde-89e5-e2a64f9a8eb1
# 5305  892a9d6f-46bc-4b14-960c-dc9e360666f6
#
#                                        Title  \
# 562                        Battlefield Earth
# 940                         Charlie's Angels
# 1652                                    Fiza
# 2417                  Joseph: King of Dreams
# 3176  Monty Python: Before the Flying Circus
# 3689             Phir Bhi Dil Hai Hindustani
# 4022             Rugrats in Paris: The Movie
# 4317                                Snow Day
# 5110                             The Patriot
# ...

# %% [markdown]
# #### Show titles of all TV Shows that was released in India

# %%
df[(df['Content Type']== "TV Show") & (df['Production Country']== "India")]['Title']
# Out:
# 245                                      Akbar Birbal
# 302                                      Alma Matters
# 510                       Bad Boy Billionaires: India
# 551                                     Bard of Blood
# 622                                            Betaal
# 642                                Bhaag Beanie Bhaag
# 758                                     Bombay Begums
# 1005    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1071                                  College Romance
# 1130                    Cricket Fever: Mumbai Indians
# 1256                                      Delhi Crime
# 1500                                Engineering Girls
# 1555                Fabulous Lives of Bollywood Wives
# 1807                                            GHOUL
# 1827                                     Girls Hostel
# 1981                                          Hasmukh
# 2250                                          Inmates
# ...

# %% [markdown]
# #### Who are the top 10 directors , who has highest number of TV Shows and Movies in Netflix?

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               15
# Jay Karas                 14
# Youssef Chahine           12
# Cathy Garcia-Molina       12
# Jay Chapman               11
# Lance Bangs                8
# Don Michael Paul           8
# Fernando Ayllón            8
# Name: count, dtype: int64

# %% [markdown]
# #### Movies where category is Comedy and Type is Movie or Country is United States

# %%
df[(df['Genres'].str.contains("Comed",case=False,na=False)) & (df['Content Type'] == "Movie") | (df['Production Country']=="United States")]
# Out:
#                                    Show Id                              Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                           (Un)Well
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                           #blackAF
# 7     c844460f-6178-4f87-929e-80816c74ca35                       #realityhigh
# 8     8b34e0e9-7258-4e49-b799-2e7eddbd7e34                          #Rucker50
# 9     6da2fc83-1546-4e9d-bf2e-9b472a059c18                            #Selfie
# ...                                    ...                                ...
# 5949  850e4be1-9128-41d0-95c6-858ed34114ed  Zipi & Zape y la Isla del Capitan
# 5953  dd7f9c40-2ee9-4d24-9c3e-b52f91f36336                         Zombieland
# 5956  80bf7986-5698-4d01-bc52-e08a8210b834                                Zoo
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5                          Zoot Suit
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                          الف مبروك
#
# ...

# %% [markdown]
# #### In how my movie/TV shows Tom Cruise was cast

# %%
df[df['Cast'].str.contains("Tom Cruise",case=False,na=False)]
# Out:
#                                    Show Id     Title  \
# 3838  8a3c098b-386a-44e4-a3a3-c5771871597e  Rain Man
#
#                                             Description        Director  \
# 3838  Motivated by money, a selfish workaholic seeki...  Barry Levinson
#
#                       Genres  \
# 3838  Classic Movies, Dramas
#
#                                                    Cast Production Country  \
# 3838  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...      United States
#
#       Release Date Rating Duration Imdb Score Content Type     Date Added  \
# 3838          1988      R  134 min     7.9/10        Movie  March 1, 2021
#
#            Date
# 3838 1988-01-01

# %% [markdown]
# #### What are the different rating defined by Netfliix

# %%
df['Rating'].nunique()
# Out:
# 11

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'TV-G', 'TV-PG', 'TV-Y', 'R', 'PG-13', 'TV-Y7',
#        'PG', 'G', nan, 'NC-17'], dtype=object)

# %% [markdown]
# #### How many movies got 'TV-14' rrating in Canada

# %%
df[(df['Content Type']== "Movie") & (df['Rating'] == "TV-14") & (df['Production Country'] == "Canada")]
# Out:
#                                    Show Id  \
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 2895  65cacd6d-e99a-4432-84c3-98a3458c94e7
# 2980  3955f108-7b46-4d45-b5f0-b48aaab8b4ba
# 5344  e31cd859-eeb7-4f63-b0ae-d3b8b9c0b882
#
#                                             Title  \
# 4                                #cats_the_mewvie
# 2895   Made You Look: A True Story About Fake Art
# 2980  Martin Matte: La vie, la mort...eh la la..!
# 5344               There's Something in the Water
#
#                                             Description  \
# 4     This pawesome documentary explores how our fel...
# 2895  A woman walks into a New York gallery with a c...
# 2980  Quebecois comedy star Martin Matte serves up e...
# 5344  This documentary spotlights the struggle of mi...
#
#                     Director                               Genres  \
# 4           Michael Margolis  Documentaries, International Movies
# 2895            Barry Avrich  Documentaries, International Movies
# ...

# %% [markdown]
# #### How many TV shows get R rating after year 2018

# %%
df[(df['Content Type']== "TV Shows") & (df['Rating'] == "R") & (df['Release Date'] > 2018)]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added, Date]
# Index: []

# %% [markdown]
# #### What is the maximum duration of movies  in Netflix?

# %%
df[df['Content Type'] == "Movie"]
# Out:
#                                    Show Id  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b
# 6     0555e67e-f624-4a05-93e4-55c117d0056d
# ...                                    ...
# 5959  29166831-eb84-4a0d-b2e0-e4c13fea7c6d
# 5961  06aab7f2-9756-4680-98cf-209b7ca86a9b
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d
#
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5959                        Zulu Man in Japan
# 5961  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# ...

# %%
df[['Minutes', 'Units']] = df['Duration'].str.split(' ', expand=True)
df
# Out:
#                                    Show Id                          Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
# ...                                    ...                            ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d                      الف مبروك
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6                   دفعة القاهرة
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                           海的儿子
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26                        반드시 잡는다
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# ...

# %%
df['Minutes'] = pd.to_numeric(df['Minutes'], errors='coerce')

# %%
df['Minutes'].max()
# Out:
# 312.0

# %% [markdown]
# #### Which indivdual country has highest number of TV Shows?

# %%
df_tv = df[df['Content Type'] == "TV Show"]

# %%
df_tv.head()
# Out:
#                                  Show Id               Title  \
# 0   cc1b6ed9-cf9e-4057-8303-34577fb54477            (Un)Well
# 3   b6611af0-f53c-4a08-9ffa-9716dc57eb9c            #blackAF
# 13  91c48de3-5bc6-43e8-ae4c-944a0b190687  100 Days My Prince
# 14  3ad83357-9327-48bb-b89d-862d61b5801e          100 Humans
# 20  ee4f5117-cf68-4862-b61c-310fb8c7379b      13 Reasons Why
#
#                                           Description Director  \
# 0   This docuseries takes a deep dive into the luc...      NaN
# 3   Kenya Barris and his family navigate relations...      NaN
# 13  Upon losing his memory, a crown prince encount...      NaN
# 14  One hundred hardy souls from diverse backgroun...      NaN
# 20  After a teenage girl's perplexing suicide, a c...      NaN
#
#                                                Genres  \
# 0                                          Reality TV
# 3                                         TV Comedies
# ...

# %%
df_tv['Production Country'].value_counts().head(1)
# Out:
# Production Country
# United States    624
# Name: count, dtype: int64

# %% [markdown]
# #### How can we sort the dataset by year

# %%
df.sort_values(by='Release Date', ascending=False)
# Out:
#                                    Show Id  \
# 1854  dca81d10-920a-47e6-b57e-c239c786bd6a
# 2072  82c37ae1-2948-4d9d-aea8-f9b0ed746442
# 2034  e60fd427-f3c0-4836-934d-4caf463e9f0f
# 5155  bf6559cf-e4de-4b2c-ad23-8efdbca5d6c2
# 5154  283e5908-4cea-4232-9951-3d41e9cf7bfb
# ...                                    ...
# 1649  95315fd3-1598-4773-95eb-2fc85d733b91
# 3706  8a6d8125-7c0f-4ec0-85dd-e1c4fdaaa380
# 2792  0418aab9-53ba-46af-8a5e-fff8fdd52684
# 2791  17fd533b-799e-4d68-8af5-03ba8c14da0a
# 2790  8d2c9141-8232-4d3d-b68e-f65a6aff2b54
#
#                                      Title  \
# 1854               Godzilla Singular Point
# 2072                History of Swear Words
# 2034       Heroes: Silence and Rock & Roll
# 5155                     The Reason I Jump
# 5154                     The Rational Life
# ...                                    ...
# 1649   Five Came Back: The Reference Films
# 3706     Pioneers: First Women Filmmakers*
# 2792  Louis C.K.: Live at the Comedy Store
# ...

# %% [markdown]
# #### Find all instances where Content Type is Movie and Genre is drama or Content Type is TV Show and Genre is Kids TV

# %%
df[((df['Content Type'] == "TV Show") & (df['Genres'].str.contains('Kids'))) | ((df['Content Type'] == "Movie") & (df['Genres'].str.contains('Drama')))]
# Out:
#                                    Show Id                Title  \
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b    #FriendButMarried
# 6     0555e67e-f624-4a05-93e4-55c117d0056d  #FriendButMarried 2
# 9     6da2fc83-1546-4e9d-bf2e-9b472a059c18              #Selfie
# 10    2aa7f08b-0321-4398-baa9-4a138f8cb9e9           #Selfie 69
# 12    eb2818f5-d01b-46fe-8797-931a767d5831       10 jours en or
# ...                                    ...                  ...
# 5955  ab343fbd-1064-405d-837c-8e99a2d0c543                  Zoo
# 5957  309b0d7e-357b-45ce-b1cf-617b4c3593d5            Zoot Suit
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5                 Zozo
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d            الف مبروك
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26              반드시 잡는다
#
#                                             Description           Director  \
# 5     Pining for his high school crush for years, a ...      Rako Prijanto
# ...
